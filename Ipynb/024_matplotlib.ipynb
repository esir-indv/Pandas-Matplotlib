# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series
import matplotlib.pyplot as plt
# 指定图像的显示位置 inline表示当前画布
# %matplotlib inline

# %%
python = Series(data=np.random.randint(50,100,size=(5)),index=["liang","feng","yuan","yu","ting"])
score = DataFrame(data={
    'python':python.values,
    'java':np.random.randint(50,100,size=(5))
},index=python.index)
display(score)
score.plot(kind='bar')
# Out:
#        python  java
# liang      70    91
# feng       76    65
# yuan       68    87
# yu         60    61
# ting       75    87
# <Axes: >

# %%
x = np.linspace(0,2*np.pi,50)
y= np.sin(x)
plt.plot(x,y)

# %%
x = np.linspace(-1,1,50)
y = (1-x**2)**0.5
plt.plot(x,y)
plt.plot(x,x**2)

# %%
# figsiez 比例,间接影响画板的颜色
fig = plt.figure(figsize=(10,5),facecolor='greenyellow')
x = np.linspace(0,2*np.pi,50)
plt.plot(x,np.sin(x)) 
plt.xlabel('plt',rotation=60,fontsize=20,color='yellow')
# 网格相关设置，颜色、透明度、粗细，边界值（在绘图函数后年设置才有效）
plt.grid(color=np.random.random(3),linestyle='--',lw=1,alpha=0.7)
# 边界值设置,也可以使用面向对象方式
plt.xlim(0,2*np.pi)
plt.ylim([4,-4])
plt.show()
fig = plt.figure(figsize=(10,5),facecolor='greenyellow')
# ================

# 获取画布 方式一
ax1 = plt.subplot(221)
# 生产网格随机颜色
ax1.grid(color=np.random.random(3),linestyle='--',lw=1,alpha=0)
plt.plot(x,np.sin(x))
# 获取画布 方式二：向指定的画板对象上添加一个子画布
ax2 = plt.subplot(339)
ax2.grid(color=np.random.random(3),linestyle='--')
ax2.set_title('ax2',loc='right',fontsize=9,color='yellow')
# 遵循上下文原则，添加到最近的画布
plt.plot(x,np.cos(x))
# 后添加画布，会覆盖前面的
ax3 = plt.subplot(337)
# 这里是个面向对象风格
ax3.plot(x,np.tan(x))
ax3.grid(color=np.random.random(3),linestyle='--')
ax3.set_xlim([0,2*np.pi])
ax3.set_ylim([-50,50])
ax3.set_xlabel('ax3',rotation=0,fontsize=14,color='blue')
ax3.set_title('ax3',fontsize=12)
# 获取4号画布,这个aspect是个灵魂，自动根据坐标轴，调整画布尺寸
ax4 = plt.subplot(222,aspect='equal')
ax4.set_xlabel('ax4',rotation=0,fontsize=14,color='pink')
ax4.set_title('ax4',fontsize=10,loc='left')
ax4.grid(color=np.random.random(3),linestyle='--',lw=1,alpha=0)
f = lambda x: (1-x**2)**0.5
x = np.linspace(-1,1,100)
y = f(x)
ax4.plot(x,y)
ax4.plot(x,-y)
ax4.plot(x,[0]*x.size)
ax4.plot([0]*x.size,x)

# %%
import seaborn as sns
# seaborn展示颜色语句
sns.palplot(np.random.random(size=(16,3)))

# %%
# seaborn预制颜色组,分类颜色组
sns.color_palette('husl')
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.7350228985632719, 0.5952719904750953, 0.1944419133847522),
#  (0.3126890019504329, 0.6928754610296064, 0.1923704830330379),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.23299120924703914, 0.639586552066035, 0.9260706093977744),
#  (0.9082572436765556, 0.40195790729656516, 0.9576909250290225)]

# %%
tips = sns.load_dataset("tips")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/http/client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/http/client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/http/client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/http/client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/http/client.py:979, in HTTPConnection.send(self, data)
#     978 if self.auto_open:
# --> 979     self.connect()
#     980 else:
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/http/client.py:1451, in HTTPSConnection.connect(self)
#    1449 "Connect to a host on a given (SSL) port."
# -> 1451 super().connect()
#    1453 if self._tunnel_host:
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/http/client.py:945, in HTTPConnection.connect(self)
#     944 sys.audit("http.client.connect", self, self.host, self.port)
# --> 945 self.sock = self._create_connection(
#     946     (self.host,self.port), self.timeout, self.source_address)
#     947 # Might fail in OSs that don't implement TCP_NODELAY
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     850 if not all_errors:
# --> 851     raise exceptions[0]
#     852 raise ExceptionGroup("create_connection failed", exceptions)
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 tips = sns.load_dataset("tips")
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/site-packages/seaborn/utils.py:588, in load_dataset(name, cache, data_home, **kws)
#     586         if name not in get_dataset_names():
#     587             raise ValueError(f"'{name}' is not one of the example datasets.")
# --> 588         urlretrieve(url, cache_path)
#     589     full_path = cache_path
#     590 else:
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/urllib/request.py:241, in urlretrieve(url, filename, reporthook, data)
#     224 """
#     225 Retrieve a URL into a temporary location on disk.
#     226
#    (...)
#     237 data file as well as the resulting HTTPMessage object.
#     238 """
#     239 url_type, path = _splittype(url)
# --> 241 with contextlib.closing(urlopen(url, data)) as fp:
#     242     headers = fp.info()
#     244     # Just return the local path and the "headers" for file://
#     245     # URLs. No sense in performing a copy unless requested.
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File ~/anaconda3/envs/Pandas&Matplotlib/lib/python3.11/urllib/request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [Errno 61] Connection refused>

# %%
tips.head()

# %% [markdown]
# 使用plt.grid可以开启网格线，使用plt面向对象的方法，创建多个子图显示不同网格线
# + lw代表linewidth，线的粗细
# + alpha表示线的明暗程度
# + color表示颜色
# + axis显示轴向

# %%
# 获取4个子画布
# 第一个画布，绘制男女性别个数的条形图
# 第二个画布，绘制吸烟者和不吸烟者的比例
# 第三个画布，绘制不同时间，消费账单的平均值
# 第四个画布，绘制消费账单和消费者的对应关系（散点图）
